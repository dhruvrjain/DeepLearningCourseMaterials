# %%
# Importing the necessary libraries
from sklearn.datasets import fetch_california_housing as fch
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# %%
# Loading the califonia housing dataset
housing = fch()

# Splitting the dataset into test and training sets
Xtrain,Xtest,Ytrain,Ytest = train_test_split(housing.data,housing.target,test_size = 0.2,random_state = 42)

l2Reg = 0.001

# Initializing the Multi-Layer Perceptron Regressor with 3 hidden layers
mlpReg = MLPRegressor(hidden_layer_sizes = [50,50,50],alpha = l2Reg,random_state = 42,max_iter = 10000)

# Creating a pipeline for preprocessing
pipeline = make_pipeline(StandardScaler(),mlpReg)

# Training the Regressor
pipeline.fit(Xtrain,Ytrain)

# Predicting the values using regression
Ypred = pipeline.predict(Xtest)

# Calculating the Root Mean Squared Error value
rmse = root_mean_squared_error(Ypred,Ytest)

# %%
print(f"RMSE: {rmse}")
print(f"No of iterations in training: {mlpReg.n_iter_}")

# Plotting the values to visualize
plt.title("Predicted house values Vs Actual housing values")
plt.xlabel("Predicted house values")
plt.ylabel("Actual house values")
plt.scatter(Ypred,Ytest)
plt.show()
# Out:
# RMSE: 0.5174801749893966
# No of iterations in training: 329
